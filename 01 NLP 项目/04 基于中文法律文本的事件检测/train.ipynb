# %%
# Link to colab drive & import packages
from google.colab import drive
drive.mount('/content/drive/')

dir_path = '/content/drive/MyDrive/Project/'

# %cd /content/drive/MyDrive/Project/
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/MyDrive/Project

# %%
# !pip install seqeval
import configparser
import torch
from utils.global_variables import Global
from utils.initializer import initialize
import pickle
import numpy as np
import pandas as pd
from utils.runner import run
from utils.load_config_global import load_config_global

# %%
# model_config  = 'Bilstm.config'
# model_config  = 'Bilstm_Crf.config'
# model_config  = 'BiGRU.config'
# model_config = 'BiGRU_Crf.config'
# model_config = 'Attention_BiGRU_Crf.config'
# model_config = 'BiGRU_Attention_Crf.config'
# model_config = 'BiGRU_EmbeddingAttention_Crf.config'
# model_config = 'BiGRU_EmbeddingAttention_Crf_weight.config'
model_config = 'BiGRU_Attention_Crf_weight.config'

# %%
config, device = load_config_global(model_config)
# Out:
# Device: cpu

# %%
parameters = initialize(config, device)
# Out:
# build CRF...
# BiGRU_Attention_Crf_weight(
#   (embedding): Embedding(
#     (embedding): Embedding(635976, 300)
#   )
#   (multihead_attention): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=400, out_features=400, bias=True)
#   )
#   (rnn): DynamicRNN(
#     (rnn): GRU(300, 200, batch_first=True, bidirectional=True)
#   )
#   (dropout): Dropout(p=0.4, inplace=False)
#   (hidden2tag): Linear(in_features=400, out_features=111, bias=True)
#   (crf): CRF()
# )

# %%
 run(parameters, config, device)

# %%
torch.save(parameters["model"].state_dict(), '.data/BiGRU_Attention_Crf_weight.pth')
