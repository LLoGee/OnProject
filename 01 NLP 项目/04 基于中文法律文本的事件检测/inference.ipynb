# %%
# Link to colab drive & import packages
from google.colab import drive
drive.mount('/content/drive/')
dir_path = '/content/drive/MyDrive/Project/'
# %cd /content/drive/MyDrive/Project/

# !pip install seqeval
import torch
from utils.load_config_global import load_config_global
from model.BiGRU_Attention_Crf_weight import BiGRU_Attention_Crf_weight
from utils.get_prediction import get_prediction
from utils.show import show
from IPython.display import HTML

model_config = 'BiGRU_Attention_Crf_weight.config'
config, device = load_config_global(model_config)
model = BiGRU_Attention_Crf_weight(config)
model.load_state_dict(torch.load('./data/BiGRU_Attention_Crf_weight.pth', map_location='cpu'))
# Out:
# Mounted at /content/drive/
# /content/drive/MyDrive/Project
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=892ca414843f115c327327e433047800047af970b0535b7a8d0340146d9aa781
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built seqeval
# ...
# Device: cpu
# build CRF...
# BiGRU_Attention_Crf_weight(
#   (embedding): Embedding(
#     (embedding): Embedding(635976, 300)
#   )
#   (multihead_attention): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=400, out_features=400, bias=True)
#   )
#   (rnn): DynamicRNN(
#     (rnn): GRU(300, 200, batch_first=True, bidirectional=True)
#   )
#   (dropout): Dropout(p=0.4, inplace=False)
#   (hidden2tag): Linear(in_features=400, out_features=111, bias=True)
#   (crf): CRF()
# )
# ...

# %% [markdown]
# ---
#
# # Inference
#
# ---

# %%
text = "另查明，被告人朱某某于2015年9月10日主动到颍上县公安局刑侦大队投案，到案后如实供述了犯罪事实"

# %%
words, prediction  = get_prediction(text, config, model, device)
print(text)
print(words)
print(prediction)
# Out:
# Building prefix dict from the default dictionary ...
# DEBUG:jieba:Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# DEBUG:jieba:Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.560 seconds.
# DEBUG:jieba:Loading model cost 0.560 seconds.
# Prefix dict has been built successfully.
# DEBUG:jieba:Prefix dict has been built successfully.
# 另查明，被告人朱某某于2015年9月10日主动到颍上县公安局刑侦大队投案，到案后如实供述了犯罪事实
# ['另', '查明', '，', '被告人', '朱', '某某', '于', '2015', '年', '9', '月', '10', '日', '主动', '到', '颍上县', '公安局', '刑侦', '大队', '投案', '，', '到案', '后', '如实', '供述', '了', '犯罪事实']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-投案', 'O', 'O', 'O', 'O', 'B-供述', 'O', 'O']

# %%
html_string = show(text, words, prediction)
HTML(html_string)
# Out:
# <p style='font-size: 20px; letter-spacing: 0px;'>Original Text:    另查明，被告人朱某某于2015年9月10日主动到颍上县公安局刑侦大队投案，到案后如实供述了犯罪事实<br></p><hr><span style="font-size: 20px;">Token & Tag:    </span><span style="border: 1px solid black; padding: 3px; color: gray; display: inline-block;font-size: 20px;">另</span> <span style="border: 1px solid black; padding: 3px; color: gray; display: inline-block;font-size: 20px;">查明</span> <span style="border: 1px solid black; padding: 3px; color: gray; display: inline-block;font-size: 20px;">，</span> <span style="border: 1px solid black; padding: 3px; color: gray; display: inline-block;font-size: 20px;">被告人</span> <span style="border: 1px solid black; padding: 3px; color: gray; display: inline-block;font-size: 20px;">朱</span> <span style="border: 1px solid black; padding: 3px; color: gray; display: inline-block;font-size: 20px;">某某</span> <span style="border: 1px solid black; padding: 3px; color: gray; display: inline-block;font-size: 20px;">于</span> <span style="b
# ...

# %%
# save to html
with open("./data/output.html", "w", encoding="utf-8") as file:
    file.write(html_string)
