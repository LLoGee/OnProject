# %% [markdown]
# ### 1. you need install the driver of chrome[the correct version]
# ### 2. you need install selenium for scrape
#     Below is the way to see the version of chrome

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Then for driver version, below link you can download chrome driver
#
#         https://chromedriver.storage.googleapis.com/index.html
# **#     If the version is not the same, most similar is ok.
#         so you can download driver 113.0.5672.24 for chrome 113.0.5672.126**
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3. After download, you extract the chromdriver.exe
#        remember the address of it
#        here the address is:
#            ‪C:\Users\V530\Downloads\chromedriver.exe
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !pip install selenium
# Out:
# ...
#      ---------------------------------------- 6.6/6.6 MB 26.2 MB/s eta 0:00:00
# ...
#      ------------------------------------- 384.9/384.9 kB 23.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 58.3/58.3 kB ? eta 0:00:00
# ...
